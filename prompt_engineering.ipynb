# %%
# set env
# !pip install yival
# !pip install openai --upgrade
# !pip install litellm --upgrade
# !pip install urllib3==1.26.18
# Out:
# ...
#   Obtaining dependency information for litellm==0.1.607 from https://files.pythonhosted.org/packages/a3/26/eb6e9bf4c22390213847184c8b8f1bcd5a8499dcb1136bafeb11624497d1/litellm-0.1.607-py3-none-any.whl.metadata
#   Using cached litellm-0.1.607-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Obtaining dependency information for openai==0.27.10 from https://files.pythonhosted.org/packages/f1/1f/3a0cb7d172f451b2ca8bf65d9196aa3b6878c010d461257c621e4bd48cad/openai-0.27.10-py3-none-any.whl.metadata
#   Using cached openai-0.27.10-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached litellm-0.1.607-py3-none-any.whl (115 kB)
# Using cached openai-0.27.10-py3-none-any.whl (76 kB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.30.1
#     Uninstalling openai-1.30.1:
#       Successfully uninstalled openai-1.30.1
#   Attempting uninstall: litellm
#     Found existing installation: litellm 1.37.16
#     Uninstalling litellm-1.37.16:
# ...

# %%
# main file running cell
import os
# azure api key
os.environ['AZURE_OPENAI_API_KEY'] = 'xxxx'
os.environ['AZURE_OPENAI_ENDPOINT'] = 'xxxx'
os.environ['AZURE_OPENAI_API_VERSION'] = '2023-12-01-preview'
os.environ['model']="xxxx"
# 控制tokens使用
os.environ['max_tokens']="1000"
# 生成任务的模版化指令（最简洁即可）【【 50字左右。"""

# %%
# run the experiment
# !yival run AutoPromptOpt_Greeting.yml
# Out:
# Generating Variations:   0%|                       | 0/5 [00:00<?, ?variation/s]----------------------
#
# input message:  [{'content': '您的目标是为gpt-4构建一个简洁的中文指令提示。指令需强调以下几点：\n- 给定一个关键词，生成一段独特且引人入胜的中文文字，能引起中国读者的共鸣。\n- 创造最吸引人的句子，并与关键词保持相关性。\n- 文字长度必须在50字左右。\n- {keyword} 代表读者提供的词语。\n- 保持输出简洁：仅包含提示内容，无任何多余内容。', 'role': 'system'}]
# ModelResponse(id='chatcmpl-9URf42am9BdYE3UcjdIV6cZUvPXb7', choices=[Choices(finish_reason='stop', index=0, message=Message(content='生成一段50字左右的文本，以{keyword}为灵感，构造最引人入胜的句子，触动中国读者的心弦。', role='assistant'))], created=1717043198, model='gpt-4', object='chat.completion', system_fingerprint='fp_7ec89fabc6', usage=Usage(completion_tokens=44, prompt_tokens=160, total_tokens=204))
# WrapperVariation(value_type='str', value='生成一段50字左右的文本，以{keyword}为灵感，构造最引人入胜的句子，触动中国读者的心弦。', instantiated_value='生成一段50字左右的文本，以{keyword}为灵感，构造最引人入胜的句子，触动中国读者的心弦。', variation_id=None)
# ----------------------
# ...
